# %% [markdown]
# <a href="https://colab.research.google.com/github/MatthewK84/Python-Code/blob/main/ProblemSet9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.signal import spectrogram

# Define the signal
fs = 1  # Normalized sampling frequency
n = np.arange(0, 16001)
x = np.cos(np.pi * n / 4 + 1000 * np.sin(np.pi * n / 8000))

# Compute the spectrogram
f, t, Sxx = spectrogram(x, fs=fs, window='rect', nperseg=256, noverlap=0, nfft=256, scaling='density')

# Plot the spectrogram
plt.figure(figsize=(10, 6))
plt.pcolormesh(t, f, 10 * np.log10(Sxx), shading='gouraud')
plt.colorbar(label='Intensity [dB]')
plt.ylabel('Frequency [normalized]')
plt.xlabel('Time [samples]')
plt.title('Spectrogram of the Signal')
plt.ylim([0, 0.5])
plt.show()
